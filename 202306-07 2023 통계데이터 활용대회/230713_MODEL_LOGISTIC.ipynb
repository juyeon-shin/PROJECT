# %%
import pandas as pd

# %%
cluster_market = pd.read_csv('clustermarket.csv')
print(len(cluster_market))
cluster_market.head(3)
# Out:
# 1307
#      시장(상점가명) 시장유형   건물형태 방송시설 이벤트광장 테마거리 아치/조형물 공용광고판 네온광고 유아놀이방어린이놀이터  ...  \
# 0  (유)문경시중앙시장  상설장  상가건물형   있음    없음   없음     없음    없음   있음          있음  ...
# 1      (주)서시장  상설장  상가건물형   있음    없음   없음     없음    없음   있음          없음  ...
# 2     (주)신정시장  상설장  상가건물형   있음    없음   없음     없음    있음   있음          없음  ...
#
#        40G_M      50G_H      50G_M      60G_H      60G_M     70GU_H  \
# 0   78984.23   95114.64   96252.35   87132.88   91576.14   39021.17
# 1  426035.70  407575.80  447418.90  314850.20  346102.60  147122.20
# 2  428591.90  385427.20  488554.60  270896.70  334566.70   87843.14
#
#       70GU_M       공실률        쾌적도  cluster_id
# 0   43281.04  0.052632  40.368421           0
# 1  166276.60  0.418605  30.097674           2
# 2  103908.60  0.093750  17.375000           2
#
# [3 rows x 52 columns]

# %%
c_data = cluster_market[cluster_market['cluster_id'] == 0]
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 618 entries, 0 to 1305
# Data columns (total 52 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   시장(상점가명)             618 non-null    object
#  1   시장유형                 618 non-null    object
#  2   건물형태                 618 non-null    object
#  3   방송시설                 618 non-null    object
#  4   이벤트광장                618 non-null    object
#  5   테마거리                 618 non-null    object
#  6   아치/조형물               618 non-null    object
#  7   공용광고판                618 non-null    object
#  8   네온광고                 618 non-null    object
#  9   유아놀이방어린이놀이터          618 non-null    object
#  10  고객휴게실                618 non-null    object
#  11  수유시설                 618 non-null    object
#  12  물품보관함                618 non-null    object
#  13  자전거보관소               618 non-null    object
#  14  카트                   618 non-null    object
# ...
