# %%
import pandas as pd

# %%
capital_market = pd.read_excel('capital_market.xlsx')
capital_market.head(5)
# Out:
#    시장(상점가명) 시장유형                               주소(도로명)   Latitude   Longitude  \
# 0      강남시장  상설장                  서울특별시 강남구 압구정로 2길 46  37.518771  127.020669
# 1      신사상가  상설장                서울특별시 강남구 압구정로29길 72-1  37.532285  127.028398
# 2    영동전통시장  상설장  서울특별시 강남구 강남대로 128길 20 영동프라자 2동 204호  37.509945  127.023674
# 3    청담삼익시장  상설장                 서울특별시 강남구 학동로 101길 26  37.522305  127.057736
# 4  고분다리전통시장  상설장                  서울특별시 강동구 구천면로34길 13  37.542506  127.131941
#
#                  주소(지번) 시장개설주기    점포수                      취급품목 홈페이지주소  \
# 0  서울특별시 강남구 신사동 510-11     매일   70.0  농산물,축산물,가공식품,의류/신발,기타소매업    NaN
# 1    서울특별시 강남구 압구정동 454     매일   90.0        농산물,수산물,가공식품,의류/신발    NaN
# 2     서울특별시 강남구 논현동 140     매일  110.0      축산물,가공식품,의류/신발,기타소매업    NaN
# 3  서울특별시 강남구 청담동 134-20     매일  183.0  농산물,축산물,가공식품,의류/신발,기타소매업    NaN
# 4  서울특별시 강동구 천호동 393-32     매일  106.0     농산물,축산물,수산물,가공식품,가정용품    NaN
#
#   공중화장실보유여부 주차장보유여부     시도
# 0         Y       Y  서울특별시
# ...

# %%
import folium

def map_reset(lat,lon):
    new_map = folium.Map([lat,lon],zoom_start=10, tiles='cartodbpositron')
    return new_map

def map_marker(new_map,df,color,radius):
    df = df[df['Latitude'].notnull() == True]
    for i in range(len(df)):
        try:
            folium.Circle([df['Latitude'][i],df['Longitude'][i]],
                      color='#fffggg',radius=radius,
                     fill_color= color).add_to(new_map)
        except:
            pass
    return new_map

# %%
new_map = map_reset(capital_market['Latitude'].mean(),capital_market['Longitude'].mean())
new_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map_marker(new_map,capital_market,'#fffggg',radius=500)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### end of script
