# %%
import pandas as pd

# %%
code_market_count = pd.read_csv('code_market_count.csv')

pop_centre = pd.read_excel('pop_centre.xlsx')

pop_lofor_in_market = pd.read_csv('pop_lofor_in_market.csv')
pop_in_market = pd.read_csv('pop_in_market.csv')

# %%
code_market_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1314 entries, 0 to 1313
# Data columns (total 49 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1314 non-null   int64
#  1   시장(상점가명)             1314 non-null   object
#  2   시장유형                 1314 non-null   object
#  3   주소(도로명)              1314 non-null   object
#  4   주소(지번)               1314 non-null   object
#  5   시장개설주기               1314 non-null   object
#  6   점포수                  1314 non-null   int64
#  7   취급품목                 1314 non-null   object
#  8   홈페이지주소               89 non-null     object
#  9   공중화장실보유여부            1314 non-null   object
#  10  주차장보유여부              1314 non-null   object
#  11  시도                   1314 non-null   object
#  12  Latitude             1314 non-null   float64
#  13  Longitude            1314 non-null   float64
#  14  명칭                   1314 non-null   object
# ...

# %%
code_market_count.head(3)
# Out:
#    Unnamed: 0    시장(상점가명) 시장유형             주소(도로명)               주소(지번)  \
# 0           0  (유)문경시중앙시장  상설장     경상북도 문경시 중앙로 87  경상북도 문경시 점촌동 197-14
# 1           1      (주)서시장  상설장  전라남도 여수시 좌수영로 16-6     전라남도 여수시 서교동 280
# 2           2     (주)신정시장  상설장  울산광역시 남구 월평로47번길 7   울산광역시 남구 신정동 630-1
#
#   시장개설주기  점포수                          취급품목                  홈페이지주소 공중화장실보유여부  \
# 0     매일   38                농산물,가공식품,기타소매업                     NaN         Y
# 1     매일  209     수산물,가공식품,의류/신발,가정용품,기타소매업                     NaN         Y
# 2     매일   87  수산물,가공식품,의류/신발,기타소매업,근린생활서비스  www.taepyung-market.kr         Y
#
#    ... market_pop_10 market_pop_lofor  market_pop_lofor_10  sido sigungu  \
# 0  ...           0.0              0.0                  0.0    경북     문경시
# 1  ...           0.0              0.0                  0.0    전남     여수시
# 2  ...           7.0              0.0                  1.0    울산      남구
#
# ...

# %%
pop_in_market.head(3)
# Out:
#    순위      관광지명                    주소   Latitude   Longitude  분류     검색수  시도  \
# 0   1  속초관광수산시장  강원 속초시 중앙로147번길 16-0  38.204541  128.590178  시장  820423  강원
# 1   1  통영중앙전통시장   경남 통영시 중앙시장1길 14-16  34.845294  128.424643  시장  681236  경남
# 2   7    오산오색시장  경기 오산시 오산로278번길 10-0  37.151605  127.069517  시장  590296  경기
#
#     종류
# 0  외지인
# 1  외지인
# 2  외지인

# %%
pop_centre.head(3)
# Out:
#          관광지명                  주소   Latitude   Longitude 중심카테고리명 대분류   순위
# 0      더현대/서울  서울 영등포구 여의대로 108-0  37.526050  126.928296     관광지  쇼핑  1.0
# 1  신세계백화점/강남점   서울 서초구 신반포로 176-0  37.504364  127.003621     관광지  쇼핑  2.0
# 2       타임스퀘어    서울 영등포구 영중로 15-0  37.517075  126.903341     관광지  쇼핑  3.0

# %%
def find_market_in_data(data,market_col):
    market = [i for i in data[market_col] if '시장' in i]
    market_in = data[data[market_col].isin(market)]
    return market_in

# %%
y = find_market_in_data(pop_centre,'관광지명')
y = y.sort_values(['관광지명']).reset_index(drop=True)
print(len(y))
y.head(3)
# Out:
# 111
#           관광지명                 주소   Latitude   Longitude 중심카테고리명 대분류    순위
# 0    1913송정역시장  광주 광산구 송정로8번길 0-0  35.135303  126.791353     관광지  쇼핑  33.0
# 1  가락동농수산물도매시장  서울 송파구 양재대로 932-0  37.493482  127.111504     관광지  쇼핑  29.0
# 2       강릉중앙시장    강원 강릉시 금성로 21-0  37.754021  128.898622     관광지  쇼핑   3.0

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   관광지명       111 non-null    object
#  1   주소         111 non-null    object
#  2   Latitude   111 non-null    float64
#  3   Longitude  111 non-null    float64
#  4   중심카테고리명    111 non-null    object
#  5   대분류        111 non-null    object
#  6   순위         111 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 6.2+ KB

# %%
import folium

def map_reset(lat,lon):
    new_map = folium.Map([lat,lon],zoom_start=7, tiles='cartodbpositron')
    return new_map

def map_marker(new_map,df,color,radius):
    df = df[df['Latitude'].notnull() == True]
    for i in range(len(df)):
        try:
            folium.Circle([df['Latitude'][i],df['Longitude'][i]],
                      color='#fffggg',radius=radius,
                     fill_color= color).add_to(new_map)
        except:
            pass
    return new_map

# %%
new_map = map_reset(code_market_count['Latitude'].mean(),code_market_count['Longitude'].mean())
map_marker(new_map,code_market_count,'green',radius=5000)
map_marker(new_map,y,'red',radius=5000)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
new_map = map_reset(code_market_count['Latitude'].mean(),code_market_count['Longitude'].mean())
map_marker(new_map,code_market_count,'green',radius=5000)
map_marker(new_map,pop_lofor_in_market,'blue',radius=5000)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
new_map = map_reset(code_market_count['Latitude'].mean(),code_market_count['Longitude'].mean())
map_marker(new_map,code_market_count,'green',radius=5000)
map_marker(new_map,pop_in_market,'blue',radius=5000)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
def caculate_distance_w_market(standard_data, data, standard_datacolumns, datacolumns, radius):
    try :
        df_list = []

        for i in range(len(standard_data)):
            current_location = (standard_data['Latitude'][i], standard_data['Longitude'][i])

            for j in range(len(data)):
                location = (data['Latitude'][j], data['Longitude'][j])
                distance = geodesic(current_location, location).meters

                if distance <= radius:
                    df_list.append([
                        standard_data[standard_datacolumns][i],
                        standard_data['Latitude'][i],
                        standard_data['Longitude'][i],
                        data[datacolumns][j],
                        data['Latitude'][j],
                        data['Longitude'][j]
                    ])
    except :
        print('pass')
        pass
    
    try:
        df = pd.DataFrame(df_list)
        df.columns = ['시장(상점가명)','Latitude','Longitude','관광지명','위도(관광지)','경도(관광지)']
        df = df.drop_duplicates(['시장(상점가명)','관광지명'], keep = 'first')
        
    except :
        pass

    return df

# %%
caculate_distance_w_market(y, code_market_count, '관광지명', '시장(상점가명)', 1000)
# Out:
# pass
# Empty DataFrame
# Columns: []
# Index: []

# %%
code_market_count[code_market_count['시장(상점가명)'].isin(list(y['관광지명']))]
# Out:
#       Unnamed: 0     시장(상점가명)   시장유형                             주소(도로명)  \
# 40            40       강화풍물시장  상설+정기              인천광역시 강화군 강화읍 중앙로 17-9
# 59            59       경주중앙시장  상설+정기                    경상북도 경주시 금성로 295
# 86            86       공주산성시장  상설+정기                     충청남도 공주시 용당길 22
# 92            92         관문시장    상설장                  대구광역시 남구 관문시장2길 43
# 108          108         광장시장    상설장                   서울특별시 종로구 창경궁로 88
# 109          109       광주양동시장    상설장                   광주광역시 서구 천변좌로 238
# 121          121        구룡포시장  상설+정기          경상북도 포항시 남구 구룡포읍 구룡포길 72-1
# 140          140         국제시장    상설장  부산광역시 중구 중구로 국제시장 2길 25호 2공구 서동 3층
# 172          172         기장시장    상설장          부산광역시 기장군 기장읍 원내로 104번길 16
# 180          180        남광주시장    상설장               광주광역시 동구 제봉로17번길 18-6
# 192          192         남부시장    상설장                   경상북도 포항시 남구 상공로43
# 203          203     남창옹기종기시장  상설+정기              울산광역시 울주군 온양읍 남창장터길 24
# ...

# %%
pop_in_market[pop_in_market['관광지명'].isin(list(y['관광지명']))]
# Out:
#      순위         관광지명                     주소   Latitude   Longitude  분류  \
