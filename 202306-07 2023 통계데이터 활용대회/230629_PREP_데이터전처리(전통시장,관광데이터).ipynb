# %%
#!pip install geopy

# %%
import pandas as pd

# %%
pop = pd.read_excel('pop.xlsx')
pop_lofor = pd.read_excel('pop_lofor.xlsx')
traditional_market = pd.read_excel('traditional_market.xlsx')
capital_market = pd.read_excel('capital_market.xlsx')

# %%
pop.head(3)
# Out:
#     순위           관광지명                 주소   Latitude   Longitude    분류  \
# 0  1.0  인천국제공항제1여객터미널    인천 중구 공항로 272-0  37.479489  126.440914  교통시설
# 1  1.0         스타필드하남  경기 하남시 미사대로 750-0  37.545485  127.223697   쇼핑몰
# 2  1.0      김포국제공항국내선   서울 강서구 하늘길 111-0  37.555890  126.808109  교통시설
#
#          검색수  시도   종류
# 0  2223643.0  인천  외지인
# 1  1945622.0  경기  외지인
# 2  1671746.0  서울  외지인

# %%
pop_lofor.head(3)
# Out:
#    언어명 시군구명    시도명            관광지명              Full Address   Latitude  \
# 0  국어권   중구  서울특별시  동대문디자인플라자(DDP)  중구 서울특별시 동대문디자인플라자(DDP)   37.566526
# 1  국어권  성동구  서울특별시             서울숲            성동구 서울특별시 서울숲   37.544388
# 2  국어권  종로구  서울특별시             익선동            종로구 서울특별시 익선동   37.574348
#
#     Longitude                                               웹사이트  \
# 0  127.009224  https://korean.visitkorea.or.kr/detail/ms_deta...
# 1  127.037442  https://korean.visitkorea.or.kr/detail/ms_deta...
# 2  126.989706  https://korean.visitkorea.or.kr/detail/ms_deta...
#
#     KTO카테고리대분류명 KTO카테고리중분류명 KTO카테고리소분류명     방문자수
# 0  인문(문화/예술/역사)       산업관광지          기타  20851.0
# 1            자연       자연관광지     자연생태관광지  13032.0
# 2  인문(문화/예술/역사)       체험관광지        이색체험  12833.0

# %%
traditional_market.head(3)
# Out:
#              시장 개설년도                           주소   Latitude   Longitude 개설주기  \
# 0          광장시장    년            서울특별시 종로구 예지동 2-1  37.570283  126.998714   상설
# 1    세종마을음식문화거리    년             서울특별시 종로구 체부동 57  37.576577  126.971747   상설
# 2  대일상가(낙원지하상가)    년  서울특별시 종로구 낙원동 288 낙원상가 지하1층  37.572666  126.987808   상설
#
#    소유관리  시장크기    시장형태     정기휴일  ...    노점  노점상인    기타    총상인  전체점포수  \
# 0  법인시장  중형시장    인정시장       평일  ...  20.0  20.0   0.0  500.0  320.0
# 1  개인시장  중형시장     상점가  모름/ 무응답  ...   0.0   0.0   0.0  308.0  109.0
# 2  공동시장  소형시장  지하도상점가       주말  ...   0.0   0.0  17.0   51.0   95.0
#
#                       조직형태      회원수 상인회 상근직원 회의실 교육장
# 0  (전통시장 특별법상) 시군구청 등록 상인회  280 명가입      1 명  있음  있음
# 1  (전통시장 특별법상) 시군구청 등록 상인회  106 명가입      1 명  있음  있음
# 2       (유통산업발전법상) 상점가진흥조합    0 명가입      0 명  없음  없음
#
# [3 rows x 48 columns]

# %%
capital_market.head(3)
# Out:
#   시장(상점가명) 시장유형                               주소(도로명)   Latitude   Longitude  \
# 0     강남시장  상설장                  서울특별시 강남구 압구정로 2길 46  37.518771  127.020669
# 1     신사상가  상설장                서울특별시 강남구 압구정로29길 72-1  37.532285  127.028398
# 2   영동전통시장  상설장  서울특별시 강남구 강남대로 128길 20 영동프라자 2동 204호  37.509945  127.023674
#
#                  주소(지번) 시장개설주기    점포수                      취급품목 홈페이지주소  \
# 0  서울특별시 강남구 신사동 510-11     매일   70.0  농산물,축산물,가공식품,의류/신발,기타소매업    NaN
# 1    서울특별시 강남구 압구정동 454     매일   90.0        농산물,수산물,가공식품,의류/신발    NaN
# 2     서울특별시 강남구 논현동 140     매일  110.0      축산물,가공식품,의류/신발,기타소매업    NaN
#
#   공중화장실보유여부 주차장보유여부     시도
# 0         Y       Y  서울특별시
# 1         Y       N  서울특별시
# 2         Y       Y  서울특별시

# %%
from geopy.distance import geodesic

# %%
def caculate_distance_w_market(standard_data, data, standard_datacolumns, datacolumns, radius):
    try :
        df_list = []

        for i in range(len(standard_data)):
            current_location = (standard_data['Latitude'][i], standard_data['Longitude'][i])

            for j in range(len(data)):
                location = (data['Latitude'][j], data['Longitude'][j])
                distance = geodesic(current_location, location).meters

                if distance <= radius:
                    df_list.append([
                        standard_data[standard_datacolumns][i],
                        standard_data['Latitude'][i],
                        standard_data['Longitude'][i],
                        data[datacolumns][j],
                        data['Latitude'][j],
                        data['Longitude'][j]
                    ])
    except :
        print('pass')
        pass
    
    try:
        df = pd.DataFrame(df_list)
        df.columns = ['시장(기준)','위도(기준)','경도(기준)','관광지명','위도(관광지)','경도(관광지)']
        df = df.drop_duplicates(['시장(상점가명)','관광지명'], keep = 'first')
        
    except :
        pass

    return df

# %%
market_pop = caculate_distance_w_market(capital_market, pop,'시장(상점가명)','관광지명',500)
market_pop.head(5)
# Out:
# pass
#    시장(기준)     위도(기준)      경도(기준)      관광지명    위도(관광지)     경도(관광지)
# 0    강남시장  37.518771  127.020669  더리버사이드호텔  37.518644  127.018101
# 1    강남시장  37.518771  127.020669  더리버사이드호텔  37.518644  127.018101
# 2  명일전통시장  37.549519  127.144913   홈플러스강동점  37.545717  127.142251
# 3    숭인시장  37.613160  127.029516  롯데백화점미아점  37.614216  127.030526
# 4   등마루시장  37.556640  126.860193   홈플러스강서점  37.558408  126.855016

# %%
market_pop['시장(상점가명)'].unique()
# Out:
# array(['강남시장', '명일전통시장', '숭인시장', '등마루시장', '경동광성상가', '경동시장', '동서시장',
#        '서울약령시장', '청량리농수산물시장', '청량리수산시장', '청량리전통시장', '청량리종합시장', '청량리청과물시장',
#        '청량종합도매시장(깡통시장)', '마포농수산물시장', '망원동월드컵시장', '망원시장', '뚝도시장', '동남상가',
#        '삼구시장', '영신상가', '영일시장', '대조시장', '제일시장', '광장시장', '동대문종합시장',
#        '동대문종합시장D동상가', '동문시장㈜', '신설종합시장', '종로신진시장', '한일상가',
#        '동대문종합시장 신관(동대문쇼핑타운)', '광희패션몰', '남대문시장', '남평화시장', '대림상가', '동평화시장',
#        '동화상가', '방산종합시장', '에리어식스(벨포스트)', '삼익패션타운', '서울중앙시장', '숭례문수입상가',
#        '신중앙시장', '신평화패션타운', '자유상가', '제일평화시장', '통일상가', '평화시장', '황학시장',
#        '면목골목시장', '우림골목시장', '고척골목시장상점가', '청계상가', '조양시장(건물형)', '테크노상가',
#        '면목시장', '영등포유통상가', 'Team204', '경안시장', '코코프라자시장', '매산시장', '역전시장',
#        '시흥삼미시장', '오색시장', '용인중앙시장', '죽전로데오상점가전통시장', '의정부시장', '의정부제일시장',
#        '금촌명동로시장', '금촌문화로시장', '금촌전통시장', '서정리시장', '통복시장', '신장전통시장',
#        '강화터미널상가', '강화풍물시장', '계양산전통시장', '석바위시장', '신기시장', '용현시장',
#        '인천남부종합시장', '간석자유시장', '구월도매전통시장', '구월시장', '만수시장', '인천모래내전통시장',
# ...

# %%
market_pop_lofor = caculate_distance_w_market(capital_market, pop_lofor,'시장(상점가명)','관광지명',2500)
market_pop_lofor.head(5)
# Out:
# pass
#   시장(기준)     위도(기준)      경도(기준)          관광지명    위도(관광지)     경도(관광지)
# 0   강남시장  37.518771  127.020669           세빛섬  37.511681  126.994719
# 1   강남시장  37.518771  127.020669       일상비일상의틈  37.500538  127.026743
# 2   강남시장  37.518771  127.020669  반포대교 달빛무지개분수  37.512633  126.998478

# %%
market_pop_lofor['시장(상점가명)'].unique()
# Out:
# array(['강남시장'], dtype=object)

# %%
import folium

def map_reset(lat,lon):
    new_map = folium.Map([lat,lon],zoom_start=10, tiles='cartodbpositron')
    return new_map

def map_marker(new_map,df,color,radius):
    df = df[df['Latitude'].notnull() == True]
    for i in range(len(df)):
        try:
            folium.Circle([df['Latitude'][i],df['Longitude'][i]],
                      color='#fffggg',radius=radius,
                     fill_color= color).add_to(new_map)
        except:
            pass
    return new_map

# %%
new_map = map_reset(capital_market['Latitude'].mean(),capital_market['Longitude'].mean())

for i in range(len(market_pop)):
    folium.Circle([market_pop['위도(기준)'][i],market_pop['경도(기준)'][i]],
                      color='#fffggg',radius=500,
                     fill_color= 'blue').add_to(new_map)

for i in range(len(market_pop)):
    folium.Circle([market_pop['위도(관광지)'][i],market_pop['경도(관광지)'][i]],
                      color='#fffggg',radius=500,
                     fill_color= 'red').add_to(new_map)
new_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
new_map = map_reset(capital_market['Latitude'].mean(),capital_market['Longitude'].mean())
new_map

folium.Circle([market_pop['위도(기준)'][0],market_pop['경도(기준)'][0]],
                      color='#fffggg',radius=2500,
                     fill_color= 'blue').add_to(new_map)

new_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i in range(len(market_pop_lofor)):
    folium.Circle([market_pop_lofor['위도(관광지)'][i],market_pop_lofor['경도(관광지)'][i]],
                      color='#fffggg',radius=2500,
                     fill_color= 'red').add_to(new_map)
new_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
caculate_distance_w_market(pop_for, pop_for,'관광지명','관광지명',10000)
# Out:
# pass
#                         시장(기준)     위도(기준)      경도(기준)  \
# 0   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 1   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 2   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 3   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 4   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 5   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 6   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 7   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 8   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 9   Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 10  Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 11  Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 12  Gyeongbokgung Palace (경복궁)  37.579617  126.977041
# 13  Gyeongbokgung Palace (경복궁)  37.579617  126.977041
#
#                                                  관광지명    위도(관광지)     경도(관광지)
# ...

# %%
caculate_distance_w_market(pop_local, pop_local,'관광지명','관광지명',10000)
# Out:
# pass
#             시장(기준)     위도(기준)      경도(기준)                    관광지명    위도(관광지)  \
# 0   동대문디자인플라자(DDP)  37.566526  127.009224          동대문디자인플라자(DDP)  37.566526
# 1   동대문디자인플라자(DDP)  37.566526  127.009224                     서울숲  37.544388
# 2   동대문디자인플라자(DDP)  37.566526  127.009224                     익선동  37.574348
# 3   동대문디자인플라자(DDP)  37.566526  127.009224                     경복궁  37.579617
# 4   동대문디자인플라자(DDP)  37.566526  127.009224   창덕궁과 후원 [유네스코 세계문화유산]  37.579900
# 5   동대문디자인플라자(DDP)  37.566526  127.009224           종로3가 귀금속 전문상가  37.570408
# 6   동대문디자인플라자(DDP)  37.566526  127.009224               그라운드시소 서촌  37.578024
# 7   동대문디자인플라자(DDP)  37.566526  127.009224                  남산서울타워  37.551169
# 8   동대문디자인플라자(DDP)  37.566526  127.009224  SK텔레콤 미래기술체험관 T.um(티움)  37.566448
# 9   동대문디자인플라자(DDP)  37.566526  127.009224                     광화문  37.575877
# 10  동대문디자인플라자(DDP)  37.566526  127.009224                하이커 그라운드  37.568589
# ...

# %%
pop_local_for = caculate_distance_w_market(pop_local, pop_for,'관광지명','관광지명',1000)
pop_local_for.head(5)
# Out:
# pass
#          시장(상점가명)     위도(시장)      경도(시장)  \
# 0  동대문디자인플라자(DDP)  37.566526  127.009224
#
#                                         관광지명    위도(관광지)     경도(관광지)
# 0  Dongdaemun Design Plaza (동대문디자인플라자 (DDP))  37.566526  127.009224

# %%
pop_local_for['관광지명'].unique()
# Out:
# array(['Dongdaemun Design Plaza (동대문디자인플라자 (DDP))'], dtype=object)

# %%
pop_local
# Out:
#      Unnamed: 0 시군구명    시도명                   관광지명   Latitude   Longitude  \
# 0           0.0   중구  서울특별시         동대문디자인플라자(DDP)  37.566526  127.009224
# 1           1.0  성동구  서울특별시                    서울숲  37.544388  127.037442
# 2           2.0  종로구  서울특별시                    익선동  37.574348  126.989706
# 3           3.0  종로구  서울특별시                    경복궁  37.579617  126.977041
# 4           4.0  종로구  서울특별시  창덕궁과 후원 [유네스코 세계문화유산]  37.579900  126.991174
# ..          ...  ...    ...                    ...        ...         ...
# 295       295.0   중구  인천광역시           씨사이드파크하늘구름광장  37.481926  126.566017
# 296       296.0  연수구  인천광역시               아트플러그 연수  37.416581  126.654770
# 297       297.0  남동구  인천광역시                  인천대공원  37.459244  126.752220
# 298       298.0   중구  인천광역시                    차덕분  37.492298  126.581106
# 299       299.0   서구  인천광역시                노을진 캠핑장  37.569699  126.656947
#
#                                             Unnamed: 3   KTO카테고리대분류명  \
# ...

# %%
pop_for
# Out:
#       Unnamed: 0  언어명 시군구명    시도명                                       관광지명  \
# 0            0.0  영어권  종로구  서울특별시                 Gyeongbokgung Palace (경복궁)
# 1            1.0  영어권  종로구  서울특별시             Bukchon Hanok Village (북촌한옥마을)
# 2            2.0  영어권  종로구  서울특별시                            Insa-dong (인사동)
# 3            3.0  영어권   중구  서울특별시  Dongdaemun Design Plaza (동대문디자인플라자 (DDP))
# 4            4.0  영어권  용산구  서울특별시                Namsan Seoul Tower (남산서울타워)
# ...          ...  ...  ...    ...                                        ...
# 1171      1171.0  중번체  옹진군  인천광역시                                  德積島 (덕적도)
# 1172      1172.0  중번체   서구  인천광역시                     仁川黔丹史前博物館 (인천 검단선사박물관)
# 1173      1173.0  중번체  옹진군  인천광역시                                  小?島 (소청도)
# 1174      1174.0  중번체  강화군  인천광역시                           玉?宇宙中心 (옥토끼우주센터)
# 1175      1175.0  중번체  강화군  인천광역시                             江華德津? (강화 덕진진)
#
#        Latitude   Longitude  \
# ...

# %%
caculate_distance_w_market(capital_market, pop_for,'시장(상점가명)','관광지명',1000)
# Out:
# pass
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### End Of Script
