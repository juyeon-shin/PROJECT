# %%
import pandas as pd
import glob

# %%
pop_local = pd.read_excel('pop_local.xlsx')
pop_for = pd.read_excel('pop_for.xlsx')

# %%
pop_local.head(3)
# Out:
#    Unnamed: 0 시군구명    시도명            관광지명   Latitude   Longitude  \
# 0         0.0   중구  서울특별시  동대문디자인플라자(DDP)  37.566526  127.009224
# 1         1.0  성동구  서울특별시             서울숲  37.544388  127.037442
# 2         2.0  종로구  서울특별시             익선동  37.574348  126.989706
#
#                                           Unnamed: 3   KTO카테고리대분류명  \
# 0  https://korean.visitkorea.or.kr/detail/ms_deta...  인문(문화/예술/역사)
# 1  https://korean.visitkorea.or.kr/detail/ms_deta...            자연
# 2  https://korean.visitkorea.or.kr/detail/ms_deta...  인문(문화/예술/역사)
#
#   KTO카테고리중분류명 KTO카테고리소분류명     방문자수
# 0       산업관광지          기타  20851.0
# 1       자연관광지     자연생태관광지  13032.0
# 2       체험관광지        이색체험  12833.0

# %%
pop_for#.head(3)
# Out:
#       Unnamed: 0  언어명 시군구명    시도명                                       관광지명  \
# 0            0.0  영어권  종로구  서울특별시                 Gyeongbokgung Palace (경복궁)
# 1            1.0  영어권  종로구  서울특별시             Bukchon Hanok Village (북촌한옥마을)
# 2            2.0  영어권  종로구  서울특별시                            Insa-dong (인사동)
# 3            3.0  영어권   중구  서울특별시  Dongdaemun Design Plaza (동대문디자인플라자 (DDP))
# 4            4.0  영어권  용산구  서울특별시                Namsan Seoul Tower (남산서울타워)
# ...          ...  ...  ...    ...                                        ...
# 1171      1171.0  중번체  옹진군  인천광역시                                  德積島 (덕적도)
# 1172      1172.0  중번체   서구  인천광역시                     仁川黔丹史前博物館 (인천 검단선사박물관)
# 1173      1173.0  중번체  옹진군  인천광역시                                  小?島 (소청도)
# 1174      1174.0  중번체  강화군  인천광역시                           玉?宇宙中心 (옥토끼우주센터)
# 1175      1175.0  중번체  강화군  인천광역시                             江華德津? (강화 덕진진)
#
#        Latitude   Longitude  \
# ...

# %%
pop_local.insert(1,'언어명','국어권')

# %%
pop_local.columns  = ['Unnamed: 0', '언어명', '시군구명', '시도명', '관광지명', 'Latitude', 'Longitude',
       '웹사이트', 'KTO카테고리대분류명', 'KTO카테고리중분류명', 'KTO카테고리소분류명', '방문자수']

# %%
pop_for.columns = ['Unnamed: 0', '언어명', '시군구명', '시도명', '관광지명', 'Latitude', 'Longitude',
       '웹사이트', 'KTO카테고리대분류명', 'KTO카테고리중분류명', 'KTO카테고리소분류명', '방문자수']

# %%
pop_lofor = pd.concat([pop_local,pop_for],axis=0)
pop_lofor.head(3)
# Out:
#    Unnamed: 0  언어명 시군구명    시도명            관광지명   Latitude   Longitude  \
# 0         0.0  국어권   중구  서울특별시  동대문디자인플라자(DDP)  37.566526  127.009224
# 1         1.0  국어권  성동구  서울특별시             서울숲  37.544388  127.037442
# 2         2.0  국어권  종로구  서울특별시             익선동  37.574348  126.989706
#
#                                                 웹사이트   KTO카테고리대분류명  \
# 0  https://korean.visitkorea.or.kr/detail/ms_deta...  인문(문화/예술/역사)
# 1  https://korean.visitkorea.or.kr/detail/ms_deta...            자연
# 2  https://korean.visitkorea.or.kr/detail/ms_deta...  인문(문화/예술/역사)
#
#   KTO카테고리중분류명 KTO카테고리소분류명     방문자수
# 0       산업관광지          기타  20851.0
# 1       자연관광지     자연생태관광지  13032.0
# 2       체험관광지        이색체험  12833.0

# %%
pop_lofor.to_excel('pop_lofor.xlsx')
