# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('DEMO_PDDE_CLAC.csv')
data
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A02357420240      1.0   A02
# 1        M000034966        여성  40대     Z07  A02357421026      1.0   A02
# 2        M000034966        여성  40대     Z07  A02358228482      1.0   A02
# 3        M000034966        여성  40대     Z07  A01016688590      1.0   A01
# 4        M000034966        여성  40대     Z07  A01016688590      1.0   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4384734  M999962961        여성  50대     Z17  A03073005783      1.0   A03
# 4384735  M999962961        여성  50대     Z17  A02034710612      1.0   A02
# 4384736  M999962961        여성  50대     Z17  A03071991818      1.0   A03
# 4384737  M999962961        여성  50대     Z17  A03071935135      1.0   A03
# 4384738  M999962961        여성  50대     Z17  A03072652674      1.0   A03
#
#             br_c    pd_c       de_dt  de_hr   buy_am  buy_ct       pd_nm  \
# ...

# %%
data['clac_hlv_nm'].unique()
# Out:
# array(['여성의류', '스포츠패션', '과자', '음료', '속옷/양말/홈웨어', '조미료', '채소', '원예/애완',
#        '냉동식품', '과일', '주류', '대용식', '건해산물', '청소/세탁/욕실용품', '완구', nan, '남성의류',
#        '아웃도어/레저', '테넌트/음식점', '패션잡화', '유아동의류', '식기/조리기구', '헬스/피트니스',
#        '화장품/뷰티케어', '양곡', '세제/위생', '퍼스널케어', '침구/수예', '병통조림', '조리식품', '모바일',
#        '문구/사무용품', '생활/주방가전', '주방잡화', '냉장식품', '생활/렌탈서비스', '기타(비상품)',
#        '유아식품', '축산물', '유제품', '수산물', '구기/필드스포츠', '가구', '건강식품', '시즌스포츠',
#        '냉장/세탁가전', '건강용품', '커피/차', '인테리어/조명', '계절가전', '담배', '공구/안전용품',
#        '자동차용품', '영상/음향가전', '출산/육아용품', '컴퓨터', '여행/레저서비스', '상품권',
#        '서적/음반/악기', '기타상품', '금융/보험서비스'], dtype=object)

# %%
about = ['스포츠패션','아웃도어/레저','헬스/피트니스','구기/필드스포츠','시즌스포츠','여행/레저서비스']

# %%
df = pd.DataFrame()

for i in about:
    data_df = data[data['clac_hlv_nm'] == i]
    df = pd.concat([df,data_df],axis=0)
    
df
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 3        M000034966        여성  40대     Z07  A01016688590      1.0   A01
# 4        M000034966        여성  40대     Z07  A01016688590      1.0   A01
# 5        M000034966        여성  40대     Z07  A01016688590      1.0   A01
# 6        M000034966        여성  40대     Z07  A01016718167      1.0   A01
# 60       M000136117        여성  30대     Z11  A01294575336      1.0   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4370880  M996403961        남성  40대     Z10  A01356343908      1.0   A01
# 4371293  M996539287        여성  30대     Z16  A01496544982      1.0   A01
# 4371294  M996539287        여성  30대     Z16  A01497077266      1.0   A01
# 4373652  M996938324        남성  30대     Z17  E06023141933      2.0   A06
# 4384735  M999962961        여성  50대     Z17  A02034710612      1.0   A02
#
#             br_c    pd_c       de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
df['clac_mcls_nm'].unique()
# Out:
# array(['스포츠잡화', '남성스포츠화', '여성스포츠화', '남성일반스포츠의류', '여성골프의류', '여성일반스포츠의류',
#        '남성등산/아웃도어의류', '남성골프의류', '유아동일반스포츠의류', '유아동스포츠화', '여성등산/아웃도어의류',
#        '기타아웃도어/레저', '캠핑', '등산', '자전거', '인라인/스케이트보드/킥보드', '낚시', '피트니스',
#        '스포츠댄스', '웨이트', '격투기', '골프', '기타구기/필드스포츠', '탁구', '배드민턴', '축구',
#        '테니스', '농구', '배구', '야구', '수영/물놀이', '스키/보드', '기타시즌스포츠', '스케이트/썰매',
#        '이용권/입장권', '여행/레저'], dtype=object)

# %%
all_s = ['기타아웃도어/레저', '캠핑', '등산', '자전거', '인라인/스케이트보드/킥보드', '낚시', '피트니스','스포츠댄스', '웨이트', '격투기', '골프', '기타구기/필드스포츠', '탁구', '배드민턴', '축구','테니스', '농구', '배구', '야구', '수영/물놀이', '스키/보드', '기타시즌스포츠', '스케이트/썰매','이용권/입장권', '여행/레저']
inside = ['피트니스', '스포츠댄스', '웨이트', '격투기', '탁구', '배드민턴', '테니스', '농구', '배구']
outside = list(set(all_s)-set(inside))

# %%
active = []

seasonal = []
